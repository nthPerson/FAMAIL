# %% [markdown]
# # Demographic metadatac creation notebook

# %%
import pandas as pd

# %%
# Source file paths
RAW_DATA_DIR = "../../raw_data/"
demographics_by_district_path = RAW_DATA_DIR + "demographics_by_district.csv"

demographics_df = pd.read_csv(demographics_by_district_path)
demographics_df.head()
# Out:
#   District  Land Area (sq km)  Year-end Permanent Population (10,000 persons)  \
# 0   Futian              78.66                                          150.17
# 1    Luohu              78.75                                          100.40
# 2  Yantian              74.91                                           22.65
# 3  Nanshan             187.47                                          135.63
# 4   Bao'an             396.61                                          301.71
#
#    Permanent Registered Population (10,000)  \
# 0                                     95.35
# 1                                     59.18
# 2                                      6.66
# 3                                     81.02
# 4                                     47.75
#
#    Permanent Non-registered Population (10,000)  \
# 0                                         54.82
# 1                                         41.22
# 2                                         15.98
# 3                                         54.61
# 4                                        253.96
#
#    Population Density (persons per sq km)  \
# 0                                   19091
# 1                                   12749
# 2                                    3024
# 3                                    7235
# 4                                    7607
#
#    Household Registration Population (10,000 persons)  Men (10,000 persons)  \
# 0                                              98.97                  49.40
# 1                                              61.19                  30.54
# 2                                               7.20                   3.62
# 3                                              85.79                  45.55
# 4                                              50.94                  26.07
#
#    Women (10,000 persons)  Sex Ratio (equal men and women = 100)  \
# 0                   49.57                                  99.65
# 1                   30.65                                  99.61
# 2                    3.58                                 101.11
# 3                   40.24                                 113.21
# 4                   24.87                                 104.76
#
#    Employee Compensation Payable (100 million yuan)  \
# 0                                            552.17
# 1                                            181.27
# 2                                             31.56
# 3                                            462.45
# 4                                            164.28
#
#    Average Number of Employed Persons (person)  \
# 0                                       557197
# 1                                       174393
# 2                                        30965
# 3                                       329039
# 4                                       186976
#
#    Average Housing Price (per sq/m)  GDP (10000 yuan)
# 0                       48902.66667          35572870
# 1                       48108.00000          19724939
# 2                       50334.33333           5375327
# 3                       49847.83333          38452711
# 4                       50647.66667          30038215

# %%
demographics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   District                                            10 non-null     object
#  1   Land Area (sq km)                                   10 non-null     float64
#  2   Year-end Permanent Population (10,000 persons)      10 non-null     float64
#  3   Permanent Registered Population (10,000)            10 non-null     float64
#  4   Permanent Non-registered Population (10,000)        10 non-null     float64
#  5   Population Density (persons per sq km)              10 non-null     int64
#  6   Household Registration Population (10,000 persons)  10 non-null     float64
#  7   Men (10,000 persons)                                10 non-null     float64
#  8   Women (10,000 persons)                              10 non-null     float64
#  9   Sex Ratio (equal men and women = 100)               10 non-null     float64
#  10  Employee Compensation Payable (100 million yuan)    10 non-null     float64
#  11  Average Number of Employed Persons (person)         10 non-null     int64
#  12  Average Housing Price (per sq/m)                    10 non-null     float64
#  13  GDP (10000 yuan)                                    10 non-null     int64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## Clean up column names

# %%
column_names = list(demographics_df.columns)

column_names[0] = 'DistrictName'
column_names[1] = 'AreaKm2'
column_names[2] = 'YearEndPermanentPop10k'
column_names[3] = 'RegisteredPermanentPop10k'
column_names[4] = 'NonRegisteredPermanentPop10k'
column_names[5] = 'PopDensityPerKm2'
column_names[6] = 'HouseholdRegisteredPop10k'
column_names[7] = 'MalePop10k'
column_names[8] = 'FemalePop10k'
column_names[9] = 'SexRatio100'
column_names[10] = 'EmployeeCompensation100MYuan'
column_names[11] = 'AvgEmployedPersons'
column_names[12] = 'AvgHousingPricePerSqM'
column_names[13] = 'GDPin10000Yuan'

column_names_dict = dict(zip(demographics_df.columns, column_names))

new_demographics_df = demographics_df.rename(columns=column_names_dict)

print(new_demographics_df.columns)
# Out:
# Index(['DistrictName', 'AreaKm2', 'YearEndPermanentPop10k',
#        'RegisteredPermanentPop10k', 'NonRegisteredPermanentPop10k',
#        'PopDensityPerKm2', 'HouseholdRegisteredPop10k', 'MalePop10k',
#        'FemalePop10k', 'SexRatio100', 'EmployeeCompensation100MYuan',
#        'AvgEmployedPersons', 'AvgHousingPricePerSqM', 'GDPin10000Yuan'],
#       dtype='object')

# %% [markdown]
# ## Generate metadata

# %%
def generate_metadata(df):
    meta_df = pd.DataFrame(index = df.columns)
    meta_df['dtype'] = df.dtypes
    meta_df['n_unique'] = df.nunique()
    meta_df['total_missing'] = df.isnull().sum()
    meta_df['is_numeric'] = meta_df['dtype'].apply(
        lambda x: pd.api.types.is_numeric_dtype(x)
    )
    meta_df['is_categorical'] = meta_df['dtype'].apply(
        lambda x: isinstance(x, pd.CategoricalDtype) or x == object
    )
    meta_df['sample_values'] = df.apply(lambda col: col.dropna().unique()[:5].tolist(), result_type='reduce')
    return meta_df

# Generate metadata
meta_df = generate_metadata(new_demographics_df)

# Export to CSV
meta_df.to_csv("all_demographics_by_district.csv")
meta_df.head(20)
# Out:
#                                 dtype  n_unique  total_missing  is_numeric  \
# DistrictName                   object        10              0       False
# AreaKm2                       float64        10              0        True
# YearEndPermanentPop10k        float64        10              0        True
# RegisteredPermanentPop10k     float64        10              0        True
# NonRegisteredPermanentPop10k  float64        10              0        True
# PopDensityPerKm2                int64        10              0        True
# HouseholdRegisteredPop10k     float64        10              0        True
# MalePop10k                    float64        10              0        True
# FemalePop10k                  float64        10              0        True
# SexRatio100                   float64        10              0        True
# EmployeeCompensation100MYuan  float64        10              0        True
# AvgEmployedPersons              int64        10              0        True
# AvgHousingPricePerSqM         float64         6              0        True
# GDPin10000Yuan                  int64        10              0        True
#
#                               is_categorical  \
# DistrictName                            True
# AreaKm2                                False
# YearEndPermanentPop10k                 False
# RegisteredPermanentPop10k              False
# NonRegisteredPermanentPop10k           False
# PopDensityPerKm2                       False
# HouseholdRegisteredPop10k              False
# MalePop10k                             False
# FemalePop10k                           False
# SexRatio100                            False
# EmployeeCompensation100MYuan           False
# AvgEmployedPersons                     False
# AvgHousingPricePerSqM                  False
# GDPin10000Yuan                         False
#
#                                                                   sample_values
# DistrictName                          [Futian, Luohu, Yantian, Nanshan, Bao'an]
# AreaKm2                                   [78.66, 78.75, 74.91, 187.47, 396.61]
# YearEndPermanentPop10k                   [150.17, 100.4, 22.65, 135.63, 301.71]
# RegisteredPermanentPop10k                    [95.35, 59.18, 6.66, 81.02, 47.75]
# NonRegisteredPermanentPop10k               [54.82, 41.22, 15.98, 54.61, 253.96]
# PopDensityPerKm2                               [19091, 12749, 3024, 7235, 7607]
# HouseholdRegisteredPop10k                     [98.97, 61.19, 7.2, 85.79, 50.94]
# MalePop10k                                    [49.4, 30.54, 3.62, 45.55, 26.07]
# FemalePop10k                                 [49.57, 30.65, 3.58, 40.24, 24.87]
# SexRatio100                              [99.65, 99.61, 101.11, 113.21, 104.76]
# EmployeeCompensation100MYuan            [552.17, 181.27, 31.56, 462.45, 164.28]
# AvgEmployedPersons                      [557197, 174393, 30965, 329039, 186976]
# AvgHousingPricePerSqM         [48902.66667, 48108.0, 50334.33333, 49847.8333...
# GDPin10000Yuan                [35572870, 19724939, 5375327, 38452711, 30038215]

# %% [markdown]
# ## Save renamed dataset and export metadata

# %%
new_demographics_df.to_csv("all_demographics_by_district.csv")

dtypes = new_demographics_df.dtypes.astype(str)
district_names = new_demographics_df["DistrictName"].tolist()

import json
with open("all_demographics_by_district.json", "w") as f:
    json.dump({
        "dtypes": dtypes.to_dict(),
        "districts": district_names
    }, f)
