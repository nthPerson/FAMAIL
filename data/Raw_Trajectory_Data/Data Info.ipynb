# %%
import pickle

# %%
taxi_07 = pickle.load(open('./taxi_record_07_50drivers.pkl', 'rb'))

# %%
print(taxi_07.keys())
print(f'Number of taxis: {len(taxi_07.keys())}')
# Out:
# dict_keys(['粤SW794X', '粤BP14B2', '粤B443ZE', '粤B2U3Y7', '粤B476ZE', '粤B158ZD', '粤B0U8G2', '粤B4U0Y3', '粤B3U4Y6', '粤B7V3P2', '粤B476YZ', '粤B4L6E1', '粤B010VY', '粤B4X2A9', '粤B0U5G6', '粤B9B35A', '粤BS3Z81', '粤B2ND30', '粤B1U9G0', '粤B9VU26', '粤B550ZB', '粤B957YZ', '粤B4NP17', '粤B7VU02', '粤B0U3G7', '粤SW948Y', '粤B1BR46', '粤B4V5X0', '粤B446ZB', '粤B9W8F2', '粤B1VW71', '粤B4U5Y9', '粤B962ZD', '粤BX2Y97', '粤B1U2G7', '粤B1U6G7', '粤B420ZE', '粤B1U6G1', '粤B1B243', '粤B0U9G0', '粤B413YZ', '粤B0V3P7', '粤BX4Y80', '粤B5AF47', '粤B4U9Y1', '粤B407ZE', '粤B4U3Y9', '粤B3387U', '粤B0DR36', '粤B553ZB'])
# Number of taxis: 50

# %%
print(f'Length of key "粤SW794X": {len(taxi_07["粤SW794X"])}')
# Out:
# Length of key "粤SW794X": 21

# %%
taxi_07['粤SW794X'][0]
# Each pickle file is a dictionary of trajectories of different drivers. Key: Plate ID, Values: Trajectories in this month
# Each Trajectory records consecutive GPS records throughout the whole day. 
# The indicator in each GPS record indicates if there is a passenger onbard (1) or not (0).
# Out:
# [['Ã§Â²Â¤SW794X', 22.82855, 114.161819, 3, 0, '2016-07-01 00:00:03'],
#  ['Ã§Â²Â¤SW794X', 22.82935, 114.160568, 18, 0, '2016-07-01 00:00:18'],
#  ['Ã§Â²Â¤SW794X', 22.8302, 114.159264, 33, 0, '2016-07-01 00:00:33'],
#  ['Ã§Â²Â¤SW794X', 22.831083, 114.158012, 48, 0, '2016-07-01 00:00:48'],
#  ['Ã§Â²Â¤SW794X', 22.831717, 114.157898, 63, 0, '2016-07-01 00:01:03'],
#  ['Ã§Â²Â¤SW794X', 22.831734, 114.157898, 78, 0, '2016-07-01 00:01:18'],
#  ['Ã§Â²Â¤SW794X', 22.831734, 114.157898, 93, 0, '2016-07-01 00:01:33'],
#  ['Ã§Â²Â¤SW794X', 22.831751, 114.157867, 108, 0, '2016-07-01 00:01:48'],
#  ['Ã§Â²Â¤SW794X', 22.845383, 114.156349, 498, 0, '2016-07-01 00:08:18'],
#  ['Ã§Â²Â¤SW794X', 22.845383, 114.156364, 528, 0, '2016-07-01 00:08:48'],
#  ['Ã§Â²Â¤SW794X', 22.845383, 114.156364, 543, 0, '2016-07-01 00:09:03'],
#  ['Ã§Â²Â¤SW794X', 22.845383, 114.156364, 558, 0, '2016-07-01 00:09:18'],
#  ['Ã§Â²Â¤SW794X', 22.845383, 114.156364, 573, 0, '2016-07-01 00:09:33'],
# ...

# %%
taxi_08 = pickle.load(open('./taxi_record_08_50drivers.pkl', 'rb'))
taxi_08['粤SW794X'][0]
# Out:
# [['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 3, 0, '2016-08-01 00:00:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 603, 0, '2016-08-01 00:10:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 1203, 0, '2016-08-01 00:20:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 1803, 0, '2016-08-01 00:30:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 2403, 0, '2016-08-01 00:40:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 3003, 0, '2016-08-01 00:50:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 4203, 0, '2016-08-01 01:10:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 4803, 0, '2016-08-01 01:20:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 5403, 0, '2016-08-01 01:30:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 6003, 0, '2016-08-01 01:40:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 6603, 0, '2016-08-01 01:50:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 7203, 0, '2016-08-01 02:00:03'],
#  ['Ã§Â²Â¤SW794X', 22.85145, 114.131264, 7803, 0, '2016-08-01 02:10:03'],
# ...

# %%
taxi_08.keys()
# Out:
# dict_keys(['粤SW794X', '粤BP14B2', '粤B443ZE', '粤B2U3Y7', '粤B476ZE', '粤B158ZD', '粤B0U8G2', '粤B4U0Y3', '粤B3U4Y6', '粤B7V3P2', '粤B476YZ', '粤B4L6E1', '粤B010VY', '粤B4X2A9', '粤B0U5G6', '粤B9B35A', '粤BS3Z81', '粤B2ND30', '粤B1U9G0', '粤B9VU26', '粤B550ZB', '粤B957YZ', '粤B4NP17', '粤B7VU02', '粤B0U3G7', '粤SW948Y', '粤B1BR46', '粤B4V5X0', '粤B446ZB', '粤B9W8F2', '粤B1VW71', '粤B4U5Y9', '粤B962ZD', '粤BX2Y97', '粤B1U2G7', '粤B1U6G7', '粤B420ZE', '粤B1U6G1', '粤B1B243', '粤B0U9G0', '粤B413YZ', '粤B0V3P7', '粤BX4Y80', '粤B5AF47', '粤B4U9Y1', '粤B407ZE', '粤B4U3Y9', '粤B3387U', '粤B0DR36', '粤B553ZB'])

# %%
# print(f'Length of taxi_record_07 for a single driver: {len(taxi_08['粤SW794X'][0])}')
len(taxi_08['粤SW794X'][0])

# print(f'Length of taxi_record_08_50drivers.pkl for a single driver: {len(taxi_08.keys()[0])}')
# Out:
# 1314

# %%
len(taxi_08['粤SW794X'])
# Out:
# 23

# %%
taxi_08['粤SW794X'][5]
# Out:
# [['Ã§Â²Â¤SW794X', 22.795116, 114.141884, 10, 0, '2016-08-08 00:00:10'],
#  ['Ã§Â²Â¤SW794X', 22.792999, 114.140816, 25, 0, '2016-08-08 00:00:25'],
#  ['Ã§Â²Â¤SW794X', 22.790751, 114.140663, 40, 0, '2016-08-08 00:00:40'],
#  ['Ã§Â²Â¤SW794X', 22.788601, 114.140915, 55, 0, '2016-08-08 00:00:55'],
#  ['Ã§Â²Â¤SW794X', 22.812716, 114.152283, 490, 1, '2016-08-08 00:08:10'],
#  ['Ã§Â²Â¤SW794X', 22.811684, 114.155983, 520, 1, '2016-08-08 00:08:40'],
#  ['Ã§Â²Â¤SW794X', 22.8125, 114.156464, 535, 1, '2016-08-08 00:08:55'],
#  ['Ã§Â²Â¤SW794X', 22.815483, 114.157829, 565, 1, '2016-08-08 00:09:25'],
#  ['Ã§Â²Â¤SW794X', 22.816816, 114.158714, 580, 1, '2016-08-08 00:09:40'],
#  ['Ã§Â²Â¤SW794X', 22.82025, 114.161003, 640, 1, '2016-08-08 00:10:40'],
#  ['Ã§Â²Â¤SW794X', 22.822132, 114.1623, 655, 1, '2016-08-08 00:10:55'],
#  ['Ã§Â²Â¤SW794X', 22.825933, 114.164886, 685, 1, '2016-08-08 00:11:25'],
#  ['Ã§Â²Â¤SW794X', 22.826134, 114.165382, 700, 1, '2016-08-08 00:11:40'],
# ...

# %%
taxi_08['粤SW794X'][-1]
# Out:
# [['Ã§Â²Â¤SW794X', 22.821251, 114.161736, 479, 0, '2016-08-31 00:07:59'],
#  ['Ã§Â²Â¤SW794X', 22.822783, 114.16275, 494, 0, '2016-08-31 00:08:14'],
#  ['Ã§Â²Â¤SW794X', 22.826015, 114.164864, 524, 0, '2016-08-31 00:08:44'],
#  ['Ã§Â²Â¤SW794X', 22.827284, 114.165787, 539, 0, '2016-08-31 00:08:59'],
#  ['Ã§Â²Â¤SW794X', 22.82835, 114.166603, 554, 0, '2016-08-31 00:09:14'],
#  ['Ã§Â²Â¤SW794X', 22.829582, 114.167534, 569, 0, '2016-08-31 00:09:29'],
#  ['Ã§Â²Â¤SW794X',
#   22.830334,
#   114.16813700000002,
#   584,
#   0,
#   '2016-08-31 00:09:44'],
#  ['Ã§Â²Â¤SW794X', 22.83045, 114.168198, 599, 0, '2016-08-31 00:09:59'],
#  ['Ã§Â²Â¤SW794X', 22.8305, 114.168213, 614, 0, '2016-08-31 00:10:14'],
#  ['Ã§Â²Â¤SW794X', 22.831066, 114.167953, 629, 0, '2016-08-31 00:10:29'],
#  ['Ã§Â²Â¤SW794X', 22.831284, 114.167519, 762, 0, '2016-08-31 00:12:42'],
#  ['Ã§Â²Â¤SW794X', 22.831551, 114.167053, 777, 0, '2016-08-31 00:12:57'],
#  ['Ã§Â²Â¤SW794X', 22.832333, 114.165848, 792, 0, '2016-08-31 00:13:12'],
# ...

# %%
taxi_07['粤SW794X'][-1]
# Out:
# [['Ã§Â²Â¤SW794X', 22.851482, 114.131149, 995, 0, '2016-07-29 00:16:35'],
#  ['Ã§Â²Â¤SW794X', 22.851482, 114.131149, 1595, 0, '2016-07-29 00:26:35'],
#  ['Ã§Â²Â¤SW794X', 22.851482, 114.131149, 2195, 0, '2016-07-29 00:36:35'],
#  ['Ã§Â²Â¤SW794X', 22.851482, 114.131149, 2795, 0, '2016-07-29 00:46:35'],
#  ['Ã§Â²Â¤SW794X', 22.851482, 114.131149, 3395, 0, '2016-07-29 00:56:35'],
#  ['Ã§Â²Â¤SW794X', 22.851482, 114.131149, 4595, 0, '2016-07-29 01:16:35'],
#  ['Ã§Â²Â¤SW794X', 22.8419, 114.160851, 39427, 0, '2016-07-29 10:57:07'],
#  ['Ã§Â²Â¤SW794X', 22.8419, 114.160851, 39457, 0, '2016-07-29 10:57:37'],
#  ['Ã§Â²Â¤SW794X', 22.8419, 114.160851, 39468, 1, '2016-07-29 10:57:48'],
#  ['Ã§Â²Â¤SW794X', 22.841516, 114.161819, 39487, 1, '2016-07-29 10:58:07'],
#  ['Ã§Â²Â¤SW794X', 22.840851, 114.16288, 39502, 1, '2016-07-29 10:58:22'],
#  ['Ã§Â²Â¤SW794X', 22.839617, 114.162514, 39517, 1, '2016-07-29 10:58:37'],
#  ['Ã§Â²Â¤SW794X', 22.837883, 114.161667, 39532, 1, '2016-07-29 10:58:52'],
# ...

# %%
taxi_09 = pickle.load(open('./taxi_record_09_50drivers.pkl', 'rb'))

print(taxi_09.keys())
# Out:
# dict_keys(['粤SW794X', '粤BP14B2', '粤B443ZE', '粤B2U3Y7', '粤B476ZE', '粤B158ZD', '粤B0U8G2', '粤B4U0Y3', '粤B3U4Y6', '粤B7V3P2', '粤B476YZ', '粤B4L6E1', '粤B010VY', '粤B4X2A9', '粤B0U5G6', '粤B9B35A', '粤BS3Z81', '粤B2ND30', '粤B1U9G0', '粤B9VU26', '粤B550ZB', '粤B957YZ', '粤B4NP17', '粤B7VU02', '粤B0U3G7', '粤SW948Y', '粤B1BR46', '粤B4V5X0', '粤B446ZB', '粤B9W8F2', '粤B1VW71', '粤B4U5Y9', '粤B962ZD', '粤BX2Y97', '粤B1U2G7', '粤B1U6G7', '粤B420ZE', '粤B1U6G1', '粤B1B243', '粤B0U9G0', '粤B413YZ', '粤B0V3P7', '粤BX4Y80', '粤B5AF47', '粤B4U9Y1', '粤B407ZE', '粤B4U3Y9', '粤B3387U', '粤B0DR36', '粤B553ZB'])
