# %% [markdown]
# # latest_traffic.pkl Data Exploration

# %%
import pickle

# %%
latest_traffic = pickle.load(open('./Data/features_condition/latest_traffic.pkl', 'rb'))

traffic_keys = list(latest_traffic.keys())
print(f'Number of keys: {len(traffic_keys)}')
# print(traffic_keys)

print(traffic_keys[:20])
# Out:
# Number of keys: 6602688
# [(36, 75, 161, 4), (44, 34, 176, 6), (31, 64, 151, 4), (26, 64, 137, 5), (25, 35, 245, 1), (35, 30, 272, 4), (17, 16, 202, 1), (45, 25, 184, 5), (29, 19, 266, 5), (46, 40, 226, 1), (7, 19, 110, 5), (26, 46, 109, 2), (28, 76, 148, 5), (18, 13, 34, 2), (29, 53, 188, 5), (45, 7, 218, 3), (37, 52, 237, 3), (32, 2, 105, 6), (33, 63, 215, 3), (38, 11, 5, 1)]

# %% [markdown]
# # Key index definition
# - 0: x_grid index
# - 1: y_grid index
# - 2: time bucket $\in$ [0,287]
# - 3: day-of-week index

# %% [markdown]
# # Value index definition

# %%
# print(latest_traffic[traffic_keys[0]])

val_element_list = ['Traffic speed', 'Waiting time', '(?)Traffic volume (unverified)']

print(f"For example key {traffic_keys[0]}:")
for i, value in enumerate(latest_traffic[traffic_keys[0]]):
    print(f'Index [{i}] = {latest_traffic[traffic_keys[0]][i]} -- {val_element_list[i]}')
    # print(f'Index [{i}] -- {val_element_list[i]}')
# Out:
# For example key (36, 75, 161, 4):
# Index [0] = 0.00016876003676169666 -- Traffic speed
# Index [1] = 0.0 -- Waiting time
# Index [2] = 15.0 -- (?)Traffic volume (unverified)
