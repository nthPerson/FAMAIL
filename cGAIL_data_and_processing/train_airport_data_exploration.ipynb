# %% [markdown]
# # train_airport.pkl Data Exploration

# %%
import pickle

# %%
train_airport = pickle.load(open('./Data/features_condition/train_airport.pkl', 'rb'))

ta_keys = train_airport.keys()
print(f'Number of PoIs in train_airport: {len(ta_keys)}')
print(ta_keys)
# Out:
# Number of PoIs in train_airport: 21
# dict_keys(['深圳北站', '深圳东站', '深圳站', '福田站', '宝安机场', '深圳西站', 'coco park', 'Mixc', 'coastal city', 'kk mall', '深圳书城', '蛇口', '华侨城', '北京大学深圳医院', '深圳市第二人民医院', '深圳市南山区人民医院', '深圳市第三人民医院', '南山区cbd', '福田cbd', '前海cbd', '罗湖区cbd'])

# %% [markdown]
# ## Contents of train_airport.pkl

# %%
for key in ta_keys:
    print(f"{key}: quant_loc: {train_airport[key][0]}; true_loc: {train_airport[key][1]}")
# Out:
# 深圳北站: quant_loc: (19, 28); true_loc: (22.6092, 114.0288)
# 深圳东站: quant_loc: (18, 37); true_loc: (22.602, 114.1189)
# 深圳站: quant_loc: (10, 37); true_loc: (22.5281, 114.1134)
# 福田站: quant_loc: (12, 31); true_loc: (22.5398, 114.0529)
# 宝安机场: quant_loc: (23, 7); true_loc: (22.639444, 113.810833)
# 深圳西站: quant_loc: (10, 16); true_loc: (22.5274, 113.9084)
# coco park: quant_loc: (11, 31); true_loc: (22.5332, 114.0544)
# Mixc: quant_loc: (12, 37); true_loc: (22.5398, 114.1109)
# coastal city: quant_loc: (10, 20); true_loc: (22.522662, 113.94271)
# kk mall: quant_loc: (13, 37); true_loc: (22.550444, 114.113385)
# 深圳书城: quant_loc: (13, 32); true_loc: (22.552693, 114.066282)
# 蛇口: quant_loc: (7, 19); true_loc: (22.497187, 113.932241)
# 华侨城: quant_loc: (12, 24); true_loc: (22.544673, 113.986156)
# 北京大学深圳医院: quant_loc: (14, 31); true_loc: (22.562208, 114.055577)
# 深圳市第二人民医院: quant_loc: (14, 35); true_loc: (22.563085, 114.092157)
# ...
